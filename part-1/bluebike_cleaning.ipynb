# %% [markdown]
# # Bluebike Boston -- Data Cleaning

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('/Users/mashitahsusanto/Desktop/GA/Mashitah_Susanto_Capstone/bluebikes_tripdata_2019.csv')

# %%
df2= pd.read_csv('/Users/mashitahsusanto/Desktop/GA/Mashitah_Susanto_Capstone/bluebikes_tripdata_2020.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # EDA for df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2522771 entries, 0 to 2522770
# Data columns (total 17 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             int64
#  1   starttime                object
#  2   stoptime                 object
#  3   start station id         int64
#  4   start station name       object
#  5   start station latitude   float64
#  6   start station longitude  float64
#  7   end station id           int64
#  8   end station name         object
#  9   end station latitude     float64
#  10  end station longitude    float64
#  11  bikeid                   int64
#  12  usertype                 object
#  13  birth year               int64
#  14  gender                   int64
#  15  year                     int64
#  16  month                    int64
# dtypes: float64(4), int64(8), object(5)
# memory usage: 327.2+ MB

# %%
df.isnull().sum()
# Out:
# tripduration               0
# starttime                  0
# stoptime                   0
# start station id           0
# start station name         0
# start station latitude     0
# start station longitude    0
# end station id             0
# end station name           0
# end station latitude       0
# end station longitude      0
# bikeid                     0
# usertype                   0
# birth year                 0
# gender                     0
# year                       0
# month                      0
# dtype: int64

# %%
df.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  2.522771e+06      2.522771e+06            2.522771e+06
# mean   2.178407e+03      1.423010e+02            4.235746e+01
# std    1.098031e+05      1.183249e+02            5.584549e-02
# min    6.100000e+01      1.000000e+00            0.000000e+00
# 25%    4.180000e+02      5.500000e+01            4.234871e+01
# 50%    7.070000e+02      9.900000e+01            4.235810e+01
# 75%    1.185000e+03      1.900000e+02            4.236599e+01
# max    4.256714e+07      4.460000e+02            4.241480e+01
#
#        start station longitude  end station id  end station latitude  \
# count             2.522771e+06    2.522771e+06          2.522771e+06
# mean             -7.108794e+01    1.416275e+02          4.235732e+01
# std               9.302137e-02    1.180612e+02          7.722553e-02
# min              -7.116649e+01    1.000000e+00          0.000000e+00
# ...

# %%
new_columns_dict = {
    'start station id':'start_ID',
'start station name':'start_name',         
'start station latitude':'start_latitude',     
'start station longitude':'start_longitude',    
'end station id': "end_ID",             
'end station name': 'end_name',          
'end station latitude':'end_latitude',      
'end station longitude':'end_longitude',
    'birth year':'birth_year'
   }

df.rename(columns=new_columns_dict, inplace=True)

# %%
df.head(3)
# Out:
#    tripduration                 starttime                  stoptime  start_ID  \
# 0           790  2019-12-01 00:01:25.3240  2019-12-01 00:14:35.3350       370
# 1           166  2019-12-01 00:05:42.8610  2019-12-01 00:08:29.3830        80
# 2           323  2019-12-01 00:08:28.5560  2019-12-01 00:13:52.4340       381
#
#                                 start_name  start_latitude  start_longitude  \
# 0               Dartmouth St at Newbury St       42.350961       -71.077828
# 1  MIT Stata Center at Vassar St / Main St       42.362131       -71.091156
# 2          Inman Square at Springfield St.       42.374384       -71.100157
#
#    end_ID                               end_name  end_latitude  end_longitude  \
# 0      33                         Kenmore Square     42.348706     -71.097009
# 1      67           MIT at Mass Ave / Amherst St     42.358100     -71.093198
# 2     221  Verizon Innovation Hub 10 Ware Street     42.372509     -71.113054
#
# ...

# %%
df.start_name.value_counts()
# Out:
# MIT at Mass Ave / Amherst St               61056
# Central Square at Mass Ave / Essex St      50997
# MIT Stata Center at Vassar St / Main St    47197
# South Station - 700 Atlantic Ave           44427
# Ames St at Main St                         39128
#                                            ...
# Washington St at Walsh Playground             33
# American Legion Hwy at Canterbury St          21
# Mobile Temporary Station 2                     3
# 8D QC Station 01                               1
# MTL-ECO5.1-01                                  1
# Name: start_name, Length: 363, dtype: int64

# %%
df.end_name.value_counts()
# Out:
# MIT at Mass Ave / Amherst St               56986
# Central Square at Mass Ave / Essex St      51442
# Ames St at Main St                         46295
# Nashua Street at Red Auerbach Way          46245
# MIT Stata Center at Vassar St / Main St    41828
#                                            ...
# American Legion Hwy at Canterbury St          22
# Mobile Temporary Station 2                     6
# Warehouse Lab PBSC                             1
# MTL-ECO4-01                                    1
# 8D QC Station 02                               1
# Name: end_name, Length: 364, dtype: int64

# %%
df['start_name']
# Out:
# 0                                 Dartmouth St at Newbury St
# 1                    MIT Stata Center at Vassar St / Main St
# 2                            Inman Square at Springfield St.
# 3                                            Third at Binney
# 4                      Verizon Innovation Hub 10 Ware Street
#                                  ...
# 2522766                                     Chinatown T Stop
# 2522767                      MIT Pacific St at Purrington St
# 2522768    Harvard University / SEAS Cruft-Pierce Halls a...
# 2522769                Central Square at Mass Ave / Essex St
# 2522770                Central Square at Mass Ave / Essex St
# Name: start_name, Length: 2522771, dtype: object

# %% [markdown]
# # EDA for df 2

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999446 entries, 0 to 1999445
# Data columns (total 18 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             int64
#  1   starttime                object
#  2   stoptime                 object
#  3   start station id         int64
#  4   start station name       object
#  5   start station latitude   float64
#  6   start station longitude  float64
#  7   end station id           int64
#  8   end station name         object
#  9   end station latitude     float64
#  10  end station longitude    float64
#  11  bikeid                   int64
#  12  usertype                 object
#  13  postal code              object
#  14  year                     int64
#  15  month                    int64
#  16  birth year               float64
#  17  gender                   float64
# dtypes: float64(6), int64(6), object(6)
# memory usage: 274.6+ MB

# %%
df2.isnull().sum()
# Out:
# tripduration                     0
# starttime                        0
# stoptime                         0
# start station id                 0
# start station name               0
# start station latitude           0
# start station longitude          0
# end station id                   0
# end station name                 0
# end station latitude             0
# end station longitude            0
# bikeid                           0
# usertype                         0
# postal code                 557309
# year                             0
# month                            0
# birth year                 1583470
# gender                     1583470
# dtype: int64

# %%
df2.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  1.999446e+06      1.999446e+06            1.999446e+06
# mean   1.850197e+03      1.631610e+02            4.235592e+01
# std    2.441864e+04      1.355034e+02            3.500467e-02
# min    6.100000e+01      1.000000e+00            0.000000e+00
# 25%    4.780000e+02      5.500000e+01            4.234522e+01
# 50%    8.340000e+02      1.100000e+02            4.235560e+01
# 75%    1.455000e+03      2.390000e+02            4.236567e+01
# max    3.879352e+06      4.920000e+02            4.241608e+01
#
#        start station longitude  end station id  end station latitude  \
# count             1.999446e+06    1.999446e+06          1.999446e+06
# mean             -7.108857e+01    1.621125e+02          4.235585e+01
# std               5.710607e-02    1.355832e+02          3.503445e-02
# min              -7.122627e+01    1.000000e+00          0.000000e+00
# ...

# %%
new_columns_dict = {
    'start station id':'start_ID',
'start station name':'start_name',         
'start station latitude':'start_latitude',     
'start station longitude':'start_longitude',    
'end station id': "end_ID",             
'end station name': 'end_name',          
'end station latitude':'end_latitude',      
'end station longitude':'end_longitude',
    'birth year':'birth_year'
   }

df2.rename(columns=new_columns_dict, inplace=True)

# %%
df2.head(3)
# Out:
#    tripduration                 starttime                  stoptime  start_ID  \
# 0          1793  2020-11-01 00:00:18.3990  2020-11-01 00:30:12.2630       186
# 1          1832  2020-11-01 00:00:34.3330  2020-11-01 00:31:07.2920       186
# 2           262  2020-11-01 00:01:54.8450  2020-11-01 00:06:17.4090       186
#
#                     start_name  start_latitude  start_longitude  end_ID  \
# 0  Congress St at Northern Ave         42.3481        -71.03764     186
# 1  Congress St at Northern Ave         42.3481        -71.03764     186
# 2  Congress St at Northern Ave         42.3481        -71.03764       7
#
#                       end_name  end_latitude  end_longitude  bikeid  \
# 0  Congress St at Northern Ave     42.348100     -71.037640    4896
# 1  Congress St at Northern Ave     42.348100     -71.037640    5630
# 2                     Fan Pier     42.353391     -71.044571    5634
#
#      usertype postal code  year  month  birth_year  gender
# ...

# %%
df2.start_name.value_counts()
# Out:
# Central Square at Mass Ave / Essex St                          32668
# Charles Circle - Charles St at Cambridge St                    31712
# MIT at Mass Ave / Amherst St                                   28286
# Christian Science Plaza - Massachusetts Ave at Westland Ave    26696
# Ames St at Main St                                             22410
#                                                                ...
# Revere City Hall                                                  13
# Blue Hill Ave at Havelock St                                      11
# Revere Public Library                                              7
# BCBS Hingham                                                       4
# MTL-ECO4-01                                                        1
# Name: start_name, Length: 386, dtype: int64

# %%
df2.end_name.value_counts()
# Out:
# Central Square at Mass Ave / Essex St                          33493
# Charles Circle - Charles St at Cambridge St                    32045
# Christian Science Plaza - Massachusetts Ave at Westland Ave    26844
# MIT at Mass Ave / Amherst St                                   26550
# Ames St at Main St                                             26113
#                                                                ...
# Revere City Hall                                                   9
# Revere Public Library                                              8
# BCBS Hingham                                                       4
# MTL-ECO4-01                                                        1
# Mobile Temporary Station 1                                         1
# Name: end_name, Length: 387, dtype: int64

# %%
df2['start_name']
# Out:
# 0                                Congress St at Northern Ave
# 1                                Congress St at Northern Ave
# 2                                Congress St at Northern Ave
# 3                        Harvard Square at Mass Ave/ Dunster
# 4                    Harvard Square at Brattle St / Eliot St
#                                  ...
# 1999441    Harvard University Gund Hall at Quincy St / Ki...
# 1999442                                        MIT Vassar St
# 1999443             Sennott Park  Broadway at Norfolk Street
# 1999444           Harvard Law School at Mass Ave / Jarvis St
# 1999445                               Main St at Thompson Sq
# Name: start_name, Length: 1999446, dtype: object

# %% [markdown]
# # Change to Datetime

# %% [markdown]
# # Summary

# %% [markdown]
# there is not really a lot of cleaning to do for this dataset, other than to change the column names, in order to make the data more compatible to use when analysing and modelling in the future.
